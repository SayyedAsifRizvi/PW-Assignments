# %% [markdown]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.27.04_a57b23ac.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.27.04_a57b23ac.jpg)

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.34.35_4a84500d.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.34.35_4a84500d.jpg)

# %% [markdown]
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.37.27_7356a395.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.37.27_7356a395.jpg)

# %% [markdown]
# c. T(n) = 2T(n/2) + c

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.39.18_e605e0eb.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.39.18_e605e0eb.jpg)

# %% [markdown]
# d. T(n) = T(n/2) + c

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.40.41_56b10553.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.40.41_56b10553.jpg)

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:
#
# a. T(n) = 2T(n-1) +1

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.42.46_9e03b4e6.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.42.46_9e03b4e6.jpg)

# %% [markdown]
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# ![WhatsApp%20Image%202024-01-09%20at%2016.44.50_5bf61a6e.jpg](attachment:WhatsApp%20Image%202024-01-09%20at%2016.44.50_5bf61a6e.jpg)
